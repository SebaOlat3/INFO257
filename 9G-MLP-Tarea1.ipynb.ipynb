# %%
import torch.nn as nn
import torch
import pandas as pd

# %%
data = pd.read_csv("Pokemon.csv")
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## Descripción de la tarea
#
# Trabajaremos con un dataset de la serie "Pokémon" que desglosa las capacidades de cada criatura en atributos cuantitativos. La tarea consiste en utilizar arquitecturas de redes neuronales simples (MLP) para identificar patrones que distingan a los Pokémon Legendarios del resto. Deberán procesar estas variables y entrenar un clasificador que maximice la capacidad predictiva sobre la variable objetivo "Legendary".
#
# Consideraciones:
# - Debe entregarlo a más tardar el 29 de mayo a las 18:00 horas.
# - Debe ser entregado al correo luis.llanca@uach.cl con el asunto "Tarea-1-MLP", el archivo debe llamarse NG-MLP-Tarea1.ipynb donde NG es el número de grupo. Es importante que el asunto sea exactamente el mismo. También, se les pedirá que se anoten en la plantilla (que se compartirá posteriormente) para una pequeña interrogación.
# - Por cada 20 minutos de retraso, se descontará una décima de la nota.
# - Si necesitan ayuda, pueden escribir a los correos luis.llanca@uach.cl, luis.llanca@cenia.cl o escribir al discord de usuario: llanking (tengo una foto de mi gata). PD: prefiero mucho más el discord.

# %% [markdown]
# ###Integrantes del grupo n°9:
# * Katherine Zapata
# * Sebastián Vásquez

# %% [markdown]
# ### Explicación del dataset
# Explique el dataset en detalle, incluyendo como mínimo una pequeña descripción de cada columna, el tipo de datos que contiene cada columna, y cualquier información adicional relevante para entender el dataset.

# %% [markdown]
# El dataset contiene información de 800 Pokémon descritos en 13 columnas, donde representa al Pokemón junto a sus caracteristocas, como el nombre, tipo, generación, estadísticas de combate y si es o no Legendary.
#
# La variable objetivo será `Legendary`, la cual indica si el Pokemón es legendario (True) o no legendario (False). Como solo son los clases posibles, diremos que el problema corresponde a una clasificación binaria supervisada. Pero para el entrenamiento cambiaremos las variables de False a 0 y el de True a 1.
#
# Las columnas principales son:
# |Columna|Descripción|
# | --- | --- |
# |`#`| Identificador numérico del Pokémon.|
# |`Name`| Nombre del Pokémon.|
# |`Type 1`| Tipo principal del Pokémon. (Grass, Fire, Water, etc.)
# |`Type 2`| Tipo secundario. 386 Pokémon no poseen el segundo tipo.
# |`Total`| Suma total de sus estadísticas base.
# |`HP`| Puntos de vida.
# |`Attack`| Ataque físico.
# |`Defense`| Defensa física.
# |`Sp. Atk`| Ataque especial.
# |`Sp. Def`| Defensa especial.
# |`Speed`| Velocidad.
# |`Generation`| Generación a la que pertenece.
# |`Legendary`| Variable booleana que indica si el Pokémon es legendario (`True`) o no (`False`).
#
# El dataset presenta un desbalance en la cantidad de no legendarios en comparación con los legendarios que solo serían 65 de 800 Pokemón. Por esta razón no usamos el accuracy como métrica, debido a que el modelo podría predecir siempre la clase mayoritaria (no legendarios) y aún así obtener un accuracy alto. Por lo tanto, usaremos recall, F1-score y precision para evaluar el desempeño del modelo.

# %% [markdown]
# ### Preparación del dataset
#
# Realice una preparación del dataset según lo que considere necesario para el entrenamiento de un modelo de clasificación. Justifique las decisiones que tome en este proceso.

# %% [markdown]
# Para entrenar el modelo se seleccionan columnas numéricas relacionadas con las estadísticas de combate, tales como `Total`, `HP`, `Attack`, `Defense`, `Sp. Atk`, `Sp. Def` y `Speed`. Estas columnas se escogieron porque son atributos que estan relacionados con las capacidades de combate de los Pokémon, lo que podría ser relevante para distinguir entre legendarios y no legendarios.
#
# La variable objetivo `Legendary` se transforma a valores numéricos:
#
# - `False` → `0`: No legendario
# - `True` → `1`: Legendario
#
# Los datos de las columnas Type 1 y Type 2 no se incluyen en el modelo, ya que al ser variables categóricas no se pueden usar directamente en un modelo de clasificación sin una codificación adecuada, y dado que el enfoque de esta tarea es utilizar un MLP simple, se opta por no incluir estas variables para evitar complicaciones adicionales en la preparación de los datos.
#
# Posteriormente, los datos se escalan mediante StandardScaler, se convierten en tensores de Pytorch y se dividen en una proporción de 60% para entrenamiento, 20% para validación y 20% para prueba.
# Esta división se realiza mediante `random_split` con una semilla fija para garantizar la reproducibilidad del experimento, lo que permite obtener la misma partición al volver a ejecutar el notebook.

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.preprocessing import StandardScaler

# 1. Cargar datos
df = pd.read_csv("Pokemon.csv")

# 2. Selección de características (Features) y Objetivo (Target)
# Seleccionamos las estadísticas numéricas que determinan si es fuerte/legendario
feature_cols = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']
X_raw = df[feature_cols].values
y_raw = df['Legendary'].astype(int).values  # Convertimos True/False a 1/0

# 3. Escalado de datos (Justificación: Las redes neuronales convergen más rápido si los datos están en la misma escala)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_raw)

# 4. Creación del Dataset personalizado (Igual que en el tutorial)
class PokemonDataset(Dataset):
    def __init__(self, features, targets):
        self.X = torch.tensor(features, dtype=torch.float32)
        self.y = torch.tensor(targets, dtype=torch.long) # Usamos long para CrossEntropyLoss
        
    def __getitem__(self, idx): #aqui se obtiene un item del dataset, por ejemplo, un pokemon con sus características y su etiqueta de legendario o no
        return self.X[idx], self.y[idx]
        
    def __len__(self):
        return len(self.y)

dataset = PokemonDataset(X_scaled, y_raw)

# 5. División del dataset (60% entrenamiento, 20% validación, 20% prueba)
train_size = int(0.6 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_set, valid_set, test_set = random_split(
    dataset, [train_size, val_size, test_size], 
    generator=torch.Generator().manual_seed(42)
)

# 6. DataLoaders (Manejadores de minibatches)
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)

print(f'Total batches - Train: {len(train_loader)}, Valid: {len(valid_loader)}, Test: {len(test_loader)}')
# Out:
# Total batches - Train: 15, Valid: 3, Test: 3

# %% [markdown]
# ### Justificación de la preparación del dataset
#
# El escalado se hace con `StandardScaler` y se utiliza porque las variables tienen rangos distintos. Por ejemplo: `Total` puede tener valores mayores que `HP` o `Speed`, y sin escalado una variable podría influir demasiado en el entrenamiento. Al estandarizar los datos, la red neuronal recibe entradas más comparables y el proceso de optimización tiende a ser más estable.
#
# La clase `PokemonDataset` convierte los datos al formato que espera PyTorch. Las entradas se guardan como `float32`, mientras que las etiquetas se guardan como `long`, lo cual es necesario para utilizar `CrossEntropyLoss`.
#
# La división en entrenamiento, validación y prueba permite separar tres propósitos: entrenar los pesos del modelo, monitorear el desempeño durante el entrenamiento y evaluar finalmente el modelo seleccionado.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gráfico de barras para ver el desbalance de la variable objetivo
plt.figure(figsize=(6,4))
sns.countplot(x='Legendary', data=df, palette='Set2')
plt.title('Distribución de Pokémon Legendarios vs No Legendarios')
plt.show()
# Out:
# C:\Users\kathe\AppData\Local\Temp\ipykernel_24040\1189113852.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Legendary', data=df, palette='Set2')

# %% [markdown]
# ### Decisión sobre las métricas por desbalance de clases
#
# El gráfico de distribución muestra que la clase `Legendary` está desbalanceada: existen muchos más Pokémon no legendarios que legendarios. Por esta razón, no se toma `accuracy` como métrica principal para seleccionar el modelo final.
#
# Si se usara solo `accuracy`, un modelo podría obtener un valor alto clasificando correctamente muchos Pokémon no legendarios, pero aun así detectar mal a los legendarios. Por ello, en la evaluación se priorizan métricas más informativas para la clase de interés: `precision`, `recall` y `F1-score`.

# %% [markdown]
# ### Definición del modelo
# Defina al menos 3 arquitecturas de redes neuronales simples (MLP) para el problema de clasificación. Justifique las decisiones que tome en la definición de cada arquitectura. Las definiciones se deben hacer en un archivo ```models.py``` e importarlas en este cuadernillo. Debe seleccionar "la mejor" arquitectura para el entrenamiento, y justificar su elección.

# %% [markdown]
# ## Definición del modelo
#
# Para resolver el problema se utilizaron redes neuronales de tipo MLP (*Multilayer Perceptron*). Una MLP es una red neuronal completamente conectada, donde cada neurona de una capa se conecta con las neuronas de la siguiente capa. En este caso, el modelo recibe como entrada las características del Pokémon y entrega como salida una predicción entre dos clases: no legendario y legendario.
#
# Se definieron tres arquitecturas con distinto nivel de complejidad. El primer modelo es una arquitectura simple sin capas ocultas, utilizada como línea base. El segundo modelo incorpora una capa oculta con activación ReLU, lo que permite aprender relaciones no lineales entre las variables. El tercer modelo contiene dos capas ocultas y una capa Dropout, lo que aumenta la capacidad del modelo y ayuda a reducir el sobreajuste durante el entrenamiento.
#
# No se selecciona un modelo final en esta etapa solo por su complejidad. Las tres arquitecturas se entrenan y luego se comparan con métricas de evaluación. Esta decisión evita asumir que el modelo más complejo es automáticamente el mejor.

# %%
from models import MLPClasificadorSimple, MLPClasificadorMedio, MLPClasificadorComplejo

modelo_simple = MLPClasificadorSimple(input_dim=7, output_dim=2)
modelo_medio = MLPClasificadorMedio(input_dim=7, output_dim=2)
modelo_complejo = MLPClasificadorComplejo(input_dim=7, output_dim=2)

print("Modelo simple:")
print(modelo_simple)

print("\nModelo medio:")
print(modelo_medio)

print("\nModelo complejo:")
print(modelo_complejo)


model = modelo_complejo
# Out:
# Modelo simple:
# MLPClasificadorSimple(
#   (output): Linear(in_features=7, out_features=2, bias=True)
# )
#
# Modelo medio:
# MLPClasificadorMedio(
#   (hidden): Linear(in_features=7, out_features=16, bias=True)
#   (activation): ReLU()
#   (output): Linear(in_features=16, out_features=2, bias=True)
# )
#
# Modelo complejo:
# MLPClasificadorComplejo(
#   (layer1): Linear(in_features=7, out_features=32, bias=True)
#   (act1): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (layer2): Linear(in_features=32, out_features=16, bias=True)
#   (act2): ReLU()
#   (output): Linear(in_features=16, out_features=2, bias=True)
# )

# %% [markdown]
# ### Definición de optimizador y función de costo
# Defina un optimizador y una función de costo adecuado para el entrenamiento del modelo. Justifique sus decisiones.

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
print("Función de pérdida configurada.")
# Out:
# Función de pérdida configurada.

# %% [markdown]
# ### Justificación de la función de pérdida
#
# Se utiliza `CrossEntropyLoss` porque los modelos entregan dos salidas: Donde cada salida corresponde a la probabilidad de pertenecer a cada clase, es decir, una para la clase `No legendario` y otra para la clase `Legendario`. Esta función de pérdida es adecuada cuando las etiquetas son enteros (`0` y `1`) y el modelo produce un puntaje para cada clase.
#
# Esto se alinea con la arquitectura definida en `models.py`, donde cada modelo tiene una capa de salida con `output_dim=2`, lo que indica que el modelo está diseñado para producir dos salidas correspondientes a las dos clases.

# %% [markdown]
# ### Entrenamiento del modelo
# Entrene el modelo seleccionado utilizando el dataset preparado. Justifique las decisiones que tome en el proceso de entrenamiento, incluyendo la selección de hiperparámetros, el número de épocas, el tamaño del batch, etc.

# %% [markdown]
# El entrenamiento se realizó para las tres arquitecturas MLP definidas: simple, media y compleja. Cada modelo fue entrenado con el mismo conjunto de entrenamiento y evaluado en cada época usando el conjunto de validación.
#
# Se utilizó la función de pérdida `CrossEntropyLoss`, ya que el problema corresponde a una clasificación con dos clases de salida: `No legendario` y `Legendario`. Los modelos entregan dos valores como salida, uno por cada clase, por lo que esta función de pérdida resulta adecuada.
#
# Como optimizador se utilizó `Adam` con una tasa de aprendizaje de `0.005`. Este optimizador fue seleccionado por su eficiencia en el entrenamiento de redes neuronales y por ajustar los parámetros de forma adaptativa. El entrenamiento se realizó durante 20 épocas, utilizando un `batch size` de 32 para entrenamiento y de 64 para validación y prueba.
#
# Durante el entrenamiento se registró la pérdida de entrenamiento y la pérdida de validación en cada época. La pérdida de validación se utilizó para guardar el mejor checkpoint de cada arquitectura. De esta forma, para cada modelo se conserva la versión que obtuvo el menor error de validación, evitando depender únicamente del último estado del entrenamiento.
#
# Finalmente, los mejores checkpoints de las tres arquitecturas fueron comparados posteriormente en el conjunto de prueba mediante precision, recall y F1-score, priorizando las métricas asociadas a la identificación de Pokémon legendarios.

# %%
from tqdm import tqdm

def entrenar_modelo(modelo, train_loader, valid_loader, criterion, num_epochs=20, lr=0.005, model_name='modelo'):
    optimizer = optim.Adam(modelo.parameters(), lr=lr)
    train_losses = []
    valid_losses = []
    best_valid_loss = float('inf')
    best_epoch = -1
    best_path = f"best_{model_name}.pt"

    print(f"\nIniciando entrenamiento para {model_name}...")

    for epoch in tqdm(range(num_epochs)):
        # --- FASE DE ENTRENAMIENTO ---
        modelo.train()
        running_train_loss = 0.0
        

        for x_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = modelo(x_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * x_batch.size(0)

        epoch_train_loss = running_train_loss / len(train_loader.dataset)
        
        train_losses.append(epoch_train_loss)

        # --- FASE DE VALIDACIÓN ---
        modelo.eval()
        running_val_loss = 0.0
        
        with torch.no_grad():
            for x_batch, y_batch in valid_loader:
                outputs = modelo(x_batch)
                loss = criterion(outputs, y_batch)

                running_val_loss += loss.item() * x_batch.size(0)

        epoch_val_loss = running_val_loss / len(valid_loader.dataset)
        
        valid_losses.append(epoch_val_loss)

         # Guardar mejor checkpoint del modelo según valid loss
        if epoch_val_loss < best_valid_loss:
            best_valid_loss = epoch_val_loss
            best_epoch = epoch + 1
            torch.save({
                'epoca': epoch + 1,
                'model_state_dict': modelo.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': epoch_val_loss
            }, best_path)

        if epoch % 10 == 0:
            print(f"Época {epoch+1:02d}/{num_epochs} -> "
                  f"Train Loss: {epoch_train_loss:.4f} || "
                  f"Val Loss: {epoch_val_loss:.4f} ")

    print(f"Mejor época para {model_name}: {best_epoch} con valid loss = {best_valid_loss:.4f}")
    print(f"Checkpoint guardado en: {best_path}")

    return {
        'model': modelo,
        'train_losses': train_losses,
        'valid_losses': valid_losses,
        'best_valid_loss': best_valid_loss,
        'best_epoch': best_epoch,
        'best_model_path': best_path
    }

modelos_a_comparar = {
    'simple': modelo_simple,
    'medio': modelo_medio,
    'complejo': modelo_complejo
}

resultados_modelos = {}
for nombre_modelo, modelo_actual in modelos_a_comparar.items():
    resultados_modelos[nombre_modelo] = entrenar_modelo(
        modelo_actual,
        train_loader,
        valid_loader,
        criterion,
        num_epochs=20,
        lr=0.005,
        model_name=nombre_modelo
    )
# Out:
# Iniciando entrenamiento para simple...
#  25%|██▌       | 5/20 [00:00<00:00, 43.49it/s]
# Época 01/20 -> Train Loss: 0.5391 || Val Loss: 0.5572
#  55%|█████▌    | 11/20 [00:00<00:00, 47.72it/s]
# Época 11/20 -> Train Loss: 0.2535 || Val Loss: 0.2686
# 100%|██████████| 20/20 [00:00<00:00, 47.06it/s]
# Mejor época para simple: 20 con valid loss = 0.2064
# Checkpoint guardado en: best_simple.pt
#
# Iniciando entrenamiento para medio...
#  20%|██        | 4/20 [00:00<00:00, 37.03it/s]
# Época 01/20 -> Train Loss: 0.7450 || Val Loss: 0.5300
#  80%|████████  | 16/20 [00:00<00:00, 37.22it/s]
# Época 11/20 -> Train Loss: 0.1063 || Val Loss: 0.1445
# 100%|██████████| 20/20 [00:00<00:00, 37.31it/s]
# Mejor época para medio: 20 con valid loss = 0.1317
# Checkpoint guardado en: best_medio.pt
#
# Iniciando entrenamiento para complejo...
#  15%|█▌        | 3/20 [00:00<00:00, 23.52it/s]
# Época 01/20 -> Train Loss: 0.5918 || Val Loss: 0.3777
#  90%|█████████ | 18/20 [00:00<00:00, 32.58it/s]
# Época 11/20 -> Train Loss: 0.0727 || Val Loss: 0.1346
# 100%|██████████| 20/20 [00:00<00:00, 30.78it/s]
# Mejor época para complejo: 8 con valid loss = 0.1325
# Checkpoint guardado en: best_complejo.pt

# %% [markdown]
# ### Justificación del proceso de entrenamiento
#
# Todas las arquitecturas se entrenan bajo las mismas condiciones para que la comparación sea lo más justa posible. Para ello, se utilizan 20 épocas, una tasa de aprendizaje de `0.005` y el optimizador `Adam`. Se eligió Adam porque ajusta los parámetros de manera adaptativa y suele dar buenos resultados en redes neuronales pequeñas y medianas.
#
# En cada época se registra tanto la pérdida de entrenamiento como la pérdida de validación. La pérdida de entrenamiento permite ver si el modelo está aprendiendo a partir de los datos con los que ajusta sus pesos. En cambio, la pérdida de validación ayuda a evaluar cómo se comporta el modelo con datos que no intervienen directamente en la actualización de sus parámetros.
#
# El checkpoint se guarda únicamente cuando disminuye la pérdida de validación. De esta forma, para cada arquitectura se conserva la mejor versión del modelo durante el entrenamiento, aunque no necesariamente corresponda a la última época. Esta decisión se basa en que la `validation loss` permite comparar el desempeño del modelo consigo mismo a lo largo del proceso de entrenamiento.

# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = range(1, len(next(iter(resultados_modelos.values()))['train_losses']) + 1)

train_losses_promedio = np.mean(
    [resultado['train_losses'] for resultado in resultados_modelos.values()],
    axis=0
)
valid_losses_promedio = np.mean(
    [resultado['valid_losses'] for resultado in resultados_modelos.values()],
    axis=0
)

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_losses_promedio, label='Pérdida Entrenamiento Promedio (3 modelos)', color='blue')
plt.plot(epochs, valid_losses_promedio, label='Pérdida Validación Promedio (3 modelos)', color='orange')
plt.title('Historial de Entrenamiento Promedio de los Modelos')
plt.xlabel('Épocas')
plt.ylabel('Costo / Pérdida (Loss)')
plt.legend()
plt.grid(alpha=0.2)
plt.savefig('curva_aprendizaje_promedio.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Interpretación de la curva promedio de pérdida
#
# La curva promedio muestra la tendencia general de la pérdida de entrenamiento y validación en las tres arquitecturas. Funciona como una vista global del proceso de entrenamiento, aunque no se toma como criterio principal para elegir el modelo final, ya que es un promedio del comportamiento de modelos diferentes.
#
# Para analizar el modelo seleccionado se utiliza después una curva individual. Esta permite revisar con mayor precisión si el modelo aprendió de manera adecuada o si presenta posibles señales de sobreajuste.

# %% [markdown]
# ### Comparación de checkpoints por pérdida de validación
# En la siguiente tabla podemos ver el mejor checkpoint alcanzado por cada arqutectura durante su propio entrenamiento

# %%
nombres_modelos = ['simple', 'medio', 'complejo']

best_valid_losses = [resultados_modelos[nombre]['best_valid_loss'] for nombre in nombres_modelos]
best_epochs = [resultados_modelos[nombre]['best_epoch'] for nombre in nombres_modelos]

resumen_checkpoints = pd.DataFrame({
    'modelo': nombres_modelos,
    'best_epoch': best_epochs,
    'best_valid_loss': best_valid_losses
})

print("=== RESUMEN DE MEJORES CHECKPOINTS ===")
print(resumen_checkpoints)

plt.figure(figsize=(8, 5))
plt.plot(nombres_modelos, best_valid_losses, marker='o', linestyle='-', label='Mejor valid loss')
plt.title('Comparación de los mejores checkpoints por modelo')
plt.xlabel('Modelo')
plt.ylabel('Best Validation Loss')
plt.grid(alpha=0.2)
plt.legend()

for x, y_val, epoca in zip(nombres_modelos, best_valid_losses, best_epochs):
    plt.text(x, y_val + 0.01, f'Época {epoca}\n{y_val:.4f}', ha='center')

plt.savefig('comparacion_mejores_checkpoints.png', bbox_inches='tight')
plt.show()
# Out:
# === RESUMEN DE MEJORES CHECKPOINTS ===
#      modelo  best_epoch  best_valid_loss
# 0    simple          20         0.206365
# 1     medio          20         0.131708
# 2  complejo           8         0.132533

# %% [markdown]
# ### Decisión sobre los checkpoints
#
# La tabla de checkpoints muestra la mejor época y la menor pérdida de validación que alcanzó cada arquitectura. Con esta información se identifica qué versión de cada modelo se conserva para hacer la comparación posterior.
#
# La pérdida de validación no se toma como el único criterio para elegir la arquitectura final. La función principal de este trabajo es seleccionar el mejor checkpoint dentro de cada modelo. La decisión final entre arquitecturas se realiza con métricas más alineadas con el objetivo del problema: identificar Pokémon legendarios.

# %% [markdown]
# ### Criterio de selección del modelo final
#
# La pérdida de validación se utiliza para seleccionar el mejor checkpoint dentro del entrenamiento de cada arquitectura. Es decir, permite escoger la mejor versión de un mismo modelo a lo largo de sus épocas de entrenamiento.
#
# Sin embargo, para escoger el modelo final entre las arquitecturas simple, media y compleja, se priorizan métricas asociadas al objetivo del problema. Como la tarea busca identificar Pokémon legendarios y el dataset está desbalanceado, se utiliza principalmente el F1-score, apoyado por recall y precision para identificar Pokémon legendarios.
#
# Por esta razón, el modelo final no se selecciona necesariamente por tener la menor pérdida de validación, sino por presentar el mejor equilibrio entre detectar Pokémon legendarios reales y evitar predicciones incorrectas.

# %% [markdown]
# ### Evaluación del modelo
# Evalúe el modelo utilizando métricas adecuadas para este problema de clasificación. Justifique la selección de las métricas utilizadas y discuta los resultados obtenidos.

# %% [markdown]
# Se evalúan los tres mejores checkpoints en el conjunto de prueba. No se utiliza `accuracy` como métrica principal debido al desbalance del dataset. Se consideran:
#
# - `Precision`: de los Pokémon predichos como legendarios, cuántos realmente eran legendarios.
# - `Recall`: de todos los Pokémon legendarios reales, cuántos detectó el modelo.
# - `F1-score`: equilibrio entre precision y recall.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

# Comparación de los 3 modelos en test

nombres_modelos = ['simple', 'medio', 'complejo']

precision_modelos = []
recall_modelos = []
f1_modelos = []

for nombre_modelo in nombres_modelos:
    info_modelo = resultados_modelos[nombre_modelo]

    checkpoint = torch.load(info_modelo['best_model_path'], map_location='cpu')

    modelo_eval = modelos_a_comparar[nombre_modelo]
    modelo_eval.load_state_dict(checkpoint['model_state_dict'])
    modelo_eval.eval()

    all_preds_metricas = []
    all_targets_metricas = []

    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            outputs = modelo_eval(x_batch)

            # Como el modelo tiene 2 salidas:
            # salida 0 = No legendario
            # salida 1 = Legendario
            # Se escoge la clase con el valor más alto.
            _, preds = torch.max(outputs, 1)

            all_preds_metricas.extend(preds.numpy())
            all_targets_metricas.extend(y_batch.numpy())

    # Métricas enfocadas en la clase 1: Pokémon legendario
    precision_modelos.append(
        precision_score(
            all_targets_metricas,
            all_preds_metricas,
            pos_label=1,
            zero_division=0
        )
    )

    recall_modelos.append(
        recall_score(
            all_targets_metricas,
            all_preds_metricas,
            pos_label=1,
            zero_division=0
        )
    )

    f1_modelos.append(
        f1_score(
            all_targets_metricas,
            all_preds_metricas,
            pos_label=1,
            zero_division=0
        )
    )


# Tabla resumen de métricas
resumen_metricas_test = pd.DataFrame({
    'modelo': nombres_modelos,
    'best_epoch': [resultados_modelos[nombre]['best_epoch'] for nombre in nombres_modelos],
    'best_valid_loss': [resultados_modelos[nombre]['best_valid_loss'] for nombre in nombres_modelos],
    'precision': precision_modelos,
    'recall': recall_modelos,
    'f1-score': f1_modelos
})

print("=== MÉTRICAS DE LOS 3 MODELOS EN TEST ===")
print(resumen_metricas_test)

# Selección automática del mejor modelo
# Criterio:
# 1. Mayor F1-score
# 2. Si empatan, mayor recall
# 3. Si empatan, mayor precision
#
# Se usa F1-score primero porque equilibra precision y recall.
# Se usa recall como segundo criterio porque nos interesa detectar legendarios.

mejor_fila = resumen_metricas_test.sort_values(
    by=['f1-score', 'recall', 'precision'],
    ascending=False
).iloc[0]

mejor_nombre_modelo = mejor_fila['modelo']

print("\n=== MODELO SELECCIONADO ===")
print("Modelo seleccionado:", mejor_nombre_modelo)
print("F1-score:", round(mejor_fila['f1-score'], 4))
print("Recall:", round(mejor_fila['recall'], 4))
print("Precision:", round(mejor_fila['precision'], 4))
print("Best valid loss:", round(mejor_fila['best_valid_loss'], 4))

# Cargar el checkpoint del mejor modelo seleccionado
checkpoint = torch.load(
    resultados_modelos[mejor_nombre_modelo]['best_model_path'],
    map_location='cpu'
)

model = modelos_a_comparar[mejor_nombre_modelo]
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

print(f"\nModelo final cargado correctamente: {mejor_nombre_modelo}")

# Gráfico comparativo de métricas
x = np.arange(len(nombres_modelos))
ancho = 0.22

plt.figure(figsize=(10, 5))

plt.bar(x - ancho, precision_modelos, width=ancho, label='Precision')
plt.bar(x, recall_modelos, width=ancho, label='Recall')
plt.bar(x + ancho, f1_modelos, width=ancho, label='F1-score')

plt.xticks(x, nombres_modelos)
plt.ylim(0, 1)
plt.title('Comparación de métricas en test para los 3 modelos')
plt.xlabel('Modelo')
plt.ylabel('Valor')
plt.grid(axis='y', alpha=0.2)
plt.legend()

for i, valor in enumerate(precision_modelos):
    plt.text(i - ancho, valor + 0.01, f'{valor:.3f}', ha='center', fontsize=9)

for i, valor in enumerate(recall_modelos):
    plt.text(i, valor + 0.01, f'{valor:.3f}', ha='center', fontsize=9)

for i, valor in enumerate(f1_modelos):
    plt.text(i + ancho, valor + 0.01, f'{valor:.3f}', ha='center', fontsize=9)

plt.tight_layout()
plt.savefig('metricas_test_comparacion_modelos.png', bbox_inches='tight')
plt.show()
# Out:
# === MÉTRICAS DE LOS 3 MODELOS EN TEST ===
#      modelo  best_epoch  best_valid_loss  precision    recall  f1-score
# 0    simple          20         0.206365   0.500000  0.307692  0.380952
# 1     medio          20         0.131708   0.545455  0.461538  0.500000
# 2  complejo           8         0.132533   0.538462  0.538462  0.538462
#
# === MODELO SELECCIONADO ===
# Modelo seleccionado: complejo
# F1-score: 0.5385
# Recall: 0.5385
# Precision: 0.5385
# Best valid loss: 0.1325
#
# Modelo final cargado correctamente: complejo

# %% [markdown]
# ### Justificación sobre el modelo final
#
# El modelo final se selecciona con base en el mayor `F1-score`, usando `recall` y `precision` como criterios de desempate. Esta decisión se tomó porque el objetivo principal no es maximizar una métrica general, sino identificar correctamente a los Pokémon legendarios.
#
# Se prioriza el `F1-score` porque mantiene un equilibrio entre `precision` y `recall`. Es decir, permite considerar tanto qué tan confiables son las predicciones de Pokémon legendarios como qué tan bien logra el modelo encontrar a los legendarios reales. Además, el `recall` se usa como segundo criterio porque, para este problema, es importante reducir la cantidad de Pokémon legendarios que el modelo no detecta.
#
# Así, el modelo seleccionado no se elige por ser más complejo, sino porque obtiene mejores resultados en las métricas que están directamente relacionadas con el objetivo planteado.

# %% [markdown]
# ### Curva de aprendizaje del modelo final
#
# Luego de seleccionar el modelo final con las métricas de test, se muestra su curva de pérdida de entrenamiento y validación.

# %%
train_losses_final = resultados_modelos[mejor_nombre_modelo]['train_losses']
valid_losses_final = resultados_modelos[mejor_nombre_modelo]['valid_losses']

epochs = range(1, len(train_losses_final) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_losses_final, label='Pérdida entrenamiento')
plt.plot(epochs, valid_losses_final, label='Pérdida validación')
plt.title(f'Curva de aprendizaje - Modelo {mejor_nombre_modelo}')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.grid(alpha=0.2)
plt.savefig(f'curva_aprendizaje_{mejor_nombre_modelo}.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Interpretación de la curva del modelo seleccionado
#
# Se puede observar la curva de pérdida de entrenamiento y validación del modelo final. Cuando ambas pérdidas disminuyen o se mantienen relativamente estables, se puede considerar que el entrenamiento tuvo un comportamiento adecuado. En cambio, si la pérdida de entrenamiento sigue bajando mientras la pérdida de validación aumenta de forma constante, podría haber señales de sobreajuste.
#
# Esta curva resulta más útil para interpretar el modelo final que la curva promedio, ya que refleja únicamente el comportamiento de la arquitectura seleccionada.

# %% [markdown]
# ### Evaluación final del modelo seleccionado
#
# La siguiente celda evalúa únicamente el modelo seleccionado automáticamente según el criterio definido anteriormente.

# %%
import os
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

best_model_path = resultados_modelos[mejor_nombre_modelo]['best_model_path']

if os.path.exists(best_model_path):
    checkpoint = torch.load(resultados_modelos[mejor_nombre_modelo]['best_model_path'] , map_location='cpu')

    model = modelos_a_comparar[mejor_nombre_modelo]
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

print(f"Modelo final evaluado: {mejor_nombre_modelo}")
print(f"Checkpoint cargado desde la época: {checkpoint['epoca']}")
print(f"Pérdida de validación del checkpoint: {checkpoint['loss']:.4f}")

model.eval()
all_preds = []
all_targets = []

with torch.no_grad(): #aquí no se calculan gradientes, solo inferencia sobre el conjunto de prueba 
    for x_batch, y_batch in test_loader:
        outputs = model(x_batch)
        _, preds = torch.max(outputs, 1)
        
        all_preds.extend(preds.numpy())
        all_targets.extend(y_batch.numpy())

# 1. Imprimir Reporte en texto plano
print("=== MATRIZ DE CONFUSIÓN BÁSICA ===")
print(confusion_matrix(all_targets, all_preds))

print("\n=== REPORTE DE CLASIFICACIÓN ===")
print(classification_report(all_targets, all_preds, target_names=['No Legendario', 'Legendario'], zero_division=0))

# 2. Desplegar la Matriz de Confusión Gráfica y Elegante
ConfusionMatrixDisplay.from_predictions(
    all_targets, 
    all_preds, 
    display_labels=['No Legendario', 'Legendario'], 
    cmap='Blues'
 )
plt.title('Matriz de Confusión - Clasificación de Pokémon')
plt.savefig(f'matriz_confusion_{mejor_nombre_modelo}.png', bbox_inches='tight')
plt.show()
# Out:
# Modelo final evaluado: complejo
# Checkpoint cargado desde la época: 8
# Pérdida de validación del checkpoint: 0.1325
# === MATRIZ DE CONFUSIÓN BÁSICA ===
# [[141   6]
#  [  6   7]]
#
# === REPORTE DE CLASIFICACIÓN ===
#                precision    recall  f1-score   support
#
# No Legendario       0.96      0.96      0.96       147
#    Legendario       0.54      0.54      0.54        13
#
#      accuracy                           0.93       160
#     macro avg       0.75      0.75      0.75       160
#  weighted avg       0.93      0.93      0.93       160

# %% [markdown]
# ### Justificación de la evaluación final
#
# La evaluación final se realiza únicamente con el modelo seleccionado de forma automática. Para esto, se carga el checkpoint correspondiente a mejor_nombre_modelo, lo cual evita evaluar por error una arquitectura distinta.
#
# La matriz de confusión permite revisar los aciertos y errores del modelo. En este problema, los falsos negativos son especialmente importantes, ya que representan Pokémon que sí son legendarios, pero que el modelo clasificó como no legendarios.
#
# El classification_report se utiliza para analizar precision, recall y F1-score por clase. Aunque el reporte también puede incluir accuracy, esta no se toma como métrica principal debido al desbalance entre clases.

# %% [markdown]
# Se revisa cuántos Pokémon legendarios y no legendarios quedaron en el conjunto de prueba.

# %%
# 1. Filtrar el DataFrame original usando los índices para aislar los 160 Pokémon
indices_test = test_set.indices

df_test_completo = df.iloc[indices_test].copy() 

# 2. CONTAR CLASES: Calcular cuántos son legendarios y cuántos no en el Test
conteos = df_test_completo['Legendary'].value_counts()
comunes_test = conteos.get(False, 0)
legendarios_test = conteos.get(True, 0)

# 3. Mostrar el resumen estadístico de las clases del examen
print(f"Total de Pokémon seleccionados para el Test: {len(df_test_completo)}")
print(f"  -> Pokémon Comunes (No Legendarios): {comunes_test}")
print(f"  -> Pokémon Legendarios Verdaderos: {legendarios_test}\n")
print("=== LISTA DE LOS 160 POKÉMON EN EL CONJUNTO DE PRUEBA ===\n")

# Configurar Pandas para que muestre las 160 filas sin recortar la lista en pantalla
pd.set_option('display.max_rows', 160)

# Desplegar la lista ordenada por su ID original para facilitar el análisis
df_test_completo[['#', 'Name', 'Type 1', 'Type 2', 'Total', 'Legendary']].sort_index()
# Out:
# Total de Pokémon seleccionados para el Test: 160
#   -> Pokémon Comunes (No Legendarios): 147
#   -> Pokémon Legendarios Verdaderos: 13
#
# === LISTA DE LOS 160 POKÉMON EN EL CONJUNTO DE PRUEBA ===
#        #                     Name    Type 1    Type 2  Total  Legendary
# 1      2                  Ivysaur     Grass    Poison    405      False
# 2      3                 Venusaur     Grass    Poison    525      False
# 6      6                Charizard      Fire    Flying    534      False
# 9      7                 Squirtle     Water       NaN    314      False
# 11     9                Blastoise     Water       NaN    530      False
# 18    15                 Beedrill       Bug    Poison    395      False
# 26    21                  Spearow    Normal    Flying    262      False
# 28    23                    Ekans    Poison       NaN    288      False
# 29    24                    Arbok    Poison       NaN    438      False
# 39    34                 Nidoking    Poison    Ground    505      False
# 40    35                 Clefairy     Fairy       NaN    323      False
# 42    37                   Vulpix      Fire       NaN    299      False
# 46    41                    Zubat    Poison    Flying    245      False
# 52    47                 Parasect       Bug     Grass    405      False
# 56    51                  Dugtrio    Ground       NaN    405      False
# 58    53                  Persian    Normal       NaN    440      False
# 76    70               Weepinbell     Grass    Poison    390      False
# 77    71               Victreebel     Grass    Poison    490      False
# 86    80                  Slowbro     Water   Psychic    490      False
# 95    88                   Grimer    Poison       NaN    325      False
# 100   93                  Haunter     Ghost    Poison    405      False
# 104   96                  Drowzee   Psychic       NaN    328      False
# 105   97                    Hypno   Psychic       NaN    483      False
# 107   99                  Kingler     Water       NaN    475      False
# 121  113                  Chansey    Normal       NaN    450      False
# 127  118                  Goldeen     Water       NaN    320      False
# 132  123                  Scyther       Bug    Flying    500      False
# 153  142               Aerodactyl      Rock    Flying    515      False
# 156  144                 Articuno       Ice    Flying    580       True
# 157  145                   Zapdos  Electric    Flying    580       True
# 177  163                 Hoothoot    Normal    Flying    262      False
# 186  172                    Pichu  Electric       NaN    205      False
# 190  176                  Togetic     Fairy    Flying    405      False
# 196  181    AmpharosMega Ampharos  Electric    Dragon    610      False
# 198  183                   Marill     Water     Fairy    250      False
# 203  188                 Skiploom     Grass    Flying    340      False
# 207  192                 Sunflora     Grass       NaN    425      False
# 208  193                    Yanma       Bug    Flying    390      False
# 209  194                   Wooper     Water    Ground    210      False
# 210  195                 Quagsire     Water    Ground    430      False
# 220  205               Forretress       Bug     Steel    465      False
# 223  208                  Steelix     Steel    Ground    510      False
# 227  211                 Qwilfish     Water    Poison    430      False
# 230  213                  Shuckle       Bug      Rock    505      False
# 232  214  HeracrossMega Heracross       Bug  Fighting    600      False
# 241  223                 Remoraid     Water       NaN    300      False
# 243  225                 Delibird       Ice    Flying    330      False
# 246  228                 Houndour      Dark      Fire    330      False
# 248  229    HoundoomMega Houndoom      Dark      Fire    600      False
# 250  231                   Phanpy    Ground       NaN    330      False
# 256  237                Hitmontop  Fighting       NaN    455      False
# 257  238                 Smoochum       Ice   Psychic    305      False
# 260  241                  Miltank    Normal       NaN    490      False
# 261  242                  Blissey    Normal       NaN    540      False
# 269  249                    Lugia   Psychic    Flying    680       True
# 276  255                  Torchic      Fire       NaN    310      False
# 277  256                Combusken      Fire  Fighting    405      False
# 281  259                Marshtomp     Water    Ground    405      False
# 299  276                  Taillow    Normal    Flying    270      False
# 300  277                  Swellow    Normal    Flying    430      False
# 306  282  GardevoirMega Gardevoir   Psychic     Fairy    618      False
# 312  288                 Vigoroth    Normal       NaN    440      False
# 314  290                  Nincada       Bug    Ground    266      False
# 319  295                  Exploud    Normal       NaN    490      False
# 321  297                 Hariyama  Fighting       NaN    474      False
# 323  299                 Nosepass      Rock       NaN    375      False
# 324  300                   Skitty    Normal       NaN    260      False
# 326  302                  Sableye      Dark     Ghost    380      False
# 329  303        MawileMega Mawile     Steel     Fairy    480      False
# 338  310                Manectric  Electric       NaN    475      False
# 343  314                 Illumise       Bug       NaN    400      False
# 345  316                   Gulpin    Poison       NaN    302      False
# 347  318                 Carvanha     Water      Dark    305      False
# 348  319                 Sharpedo     Water      Dark    460      False
# 353  323                 Camerupt      Fire    Ground    460      False
# 362  331                   Cacnea     Grass       NaN    335      False
# 365  334                  Altaria    Dragon    Flying    490      False
# 366  334      AltariaMega Altaria    Dragon     Fairy    590      False
# 376  344                  Claydol    Ground   Psychic    500      False
# 388  355                  Duskull     Ghost       NaN    295      False
# 389  356                 Dusclops     Ghost       NaN    455      False
# 399  364                   Sealeo       Ice     Water    410      False
# 411  375                   Metang     Steel   Psychic    420      False
# 414  377                 Regirock      Rock       NaN    580       True
# 420  381        LatiosMega Latios    Dragon   Psychic    700       True
# 423  383                  Groudon    Ground       NaN    670       True
# 428  386       DeoxysNormal Forme   Psychic       NaN    600       True
# 438  393                   Piplup     Water       NaN    314      False
# 440  395                 Empoleon     Water     Steel    530      False
# 442  397                 Staravia    Normal    Flying    340      False
# 445  400                  Bibarel    Normal     Water    410      False
# 456  411                Bastiodon      Rock     Steel    495      False
# 461  414                   Mothim       Bug    Flying    424      False
# 462  415                   Combee       Bug    Flying    244      False
# 465  418                   Buizel     Water       NaN    330      False
# 469  422                  Shellos     Water       NaN    325      False
# 471  424                  Ambipom    Normal       NaN    482      False
# 482  434                   Stunky    Poison      Dark    329      False
# 484  436                  Bronzor     Steel   Psychic    300      False
# 485  437                 Bronzong     Steel   Psychic    500      False
# 487  439                 Mime Jr.   Psychic     Fairy    310      False
# 488  440                  Happiny    Normal       NaN    220      False
# 515  464                Rhyperior    Ground      Rock    535      False
# 528  476                Probopass      Rock     Steel    525      False
# 534  479         RotomFrost Rotom  Electric       Ice    520      False
# 536  479           RotomMow Rotom  Electric     Grass    520      False
# 543  486                Regigigas    Normal       NaN    670       True
# 546  488                Cresselia   Psychic       NaN    600      False
# 547  489                   Phione     Water       NaN    480      False
# 549  491                  Darkrai      Dark       NaN    600       True
# 550  492        ShayminLand Forme     Grass       NaN    600       True
# 554  495                    Snivy     Grass       NaN    308      False
# 555  496                  Servine     Grass       NaN    413      False
# 557  498                    Tepig      Fire       NaN    308      False
# 568  509                 Purrloin      Dark       NaN    281      False
# 570  511                  Pansage     Grass       NaN    316      False
# 574  515                  Panpour     Water       NaN    316      False
# 577  518                 Musharna   Psychic       NaN    487      False
# 578  519                   Pidove    Normal    Flying    264      False
# 581  522                  Blitzle  Electric       NaN    295      False
# 594  534               Conkeldurr  Fighting       NaN    505      False
# 601  541                 Swadloon       Bug     Grass    380      False
# 608  548                  Petilil     Grass       NaN    280      False
# 609  549                Lilligant     Grass       NaN    480      False
# 611  551                  Sandile    Ground      Dark    292      False
# 615  555  DarmanitanStandard Mode      Fire       NaN    480      False
# 617  556                 Maractus     Grass       NaN    461      False
# 622  561                 Sigilyph   Psychic    Flying    490      False
# 628  567                 Archeops      Rock    Flying    567      False
# 643  582                Vanillite       Ice       NaN    305      False
# 654  593                Jellicent     Water     Ghost    480      False
# 662  601                Klinklang     Steel       NaN    520      False
# 666  605                   Elgyem   Psychic       NaN    335      False
# 668  607                  Litwick     Ghost      Fire    275      False
# 672  611                  Fraxure    Dragon       NaN    410      False
# 673  612                  Haxorus    Dragon       NaN    540      False
# 680  619                  Mienfoo  Fighting       NaN    350      False
# 687  626               Bouffalant    Normal       NaN    490      False
# 691  630                Mandibuzz      Dark    Flying    510      False
# 705  642   ThundurusTherian Forme  Electric    Flying    580       True
# 707  644                   Zekrom    Dragon  Electric    680       True
# 714  647     KeldeoResolute Forme     Water  Fighting    580      False
# 715  648       MeloettaAria Forme    Normal   Psychic    600      False
# 717  649                 Genesect       Bug     Steel    600      False
# 718  650                  Chespin     Grass       NaN    313      False
# 719  651                Quilladin     Grass       NaN    405      False
# 720  652               Chesnaught     Grass  Fighting    530      False
# 725  657                Frogadier     Water       NaN    405      False
# 731  663               Talonflame      Fire    Flying    499      False
# 733  665                   Spewpa       Bug       NaN    213      False
# 741  673                   Gogoat     Grass       NaN    531      False
# 751  681    AegislashShield Forme     Steel     Ghost    520      False
# 753  683               Aromatisse     Fairy       NaN    462      False
# 756  686                    Inkay      Dark   Psychic    288      False
# 767  697                Tyrantrum      Rock    Dragon    521      False
# 768  698                   Amaura      Rock       Ice    362      False
# 776  706                   Goodra    Dragon       NaN    600      False
# 777  707                   Klefki     Steel     Fairy    470      False
# 791  715                  Noivern    Flying    Dragon    535      False
# 796  719      DiancieMega Diancie      Rock     Fairy    700       True

# %% [markdown]
# ### Justificación de revisar el conjunto de prueba
#
# Se revisa la distribución de Pokémon legendarios y no legendarios en el conjunto de prueba para interpretar correctamente las métricas finales. Como el dataset está desbalanceado, es importante conocer cuántos casos legendarios reales hay en `test` antes de analizar `recall`, `precision`, falsos positivos y falsos negativos.

# %%
# 1. Filtrar el DataFrame original usando esos índices
df_test_pokemon = df.iloc[indices_test].copy()

# 2. Añadir la columna con las predicciones guardadas en la lista 'all_preds'
df_test_pokemon['Prediccion_Modelo'] = all_preds

# 3. Mapear los números (0 y 1) a texto legible
df_test_pokemon['Prediccion_Modelo'] = df_test_pokemon['Prediccion_Modelo'].map({0: 'No Legendario', 1: 'Legendario'})
df_test_pokemon['Real_Texto'] = df_test_pokemon['Legendary'].map({False: 'No Legendario', True: 'Legendario'})

# 4. Filtrar e imprimir únicamente los Pokémon donde el modelo se equivocó
df_errores = df_test_pokemon[df_test_pokemon['Prediccion_Modelo'] != df_test_pokemon['Real_Texto']]

print(f"Modelo analizado: {mejor_nombre_modelo}")

print(f"Total de errores encontrados en el grupo de prueba: {len(df_errores)}\n")
print("=== DETALLE DE POKÉMON MAL CLASIFICADOS ===")
df_errores[['Name', 'Total', 'HP', 'Attack', 'Defense', 'Real_Texto', 'Prediccion_Modelo']]
# Out:
# Modelo analizado: complejo
# Total de errores encontrados en el grupo de prueba: 12
#
# === DETALLE DE POKÉMON MAL CLASIFICADOS ===
#                         Name  Total   HP  Attack  Defense     Real_Texto  \
# 543                Regigigas    670  110     160      110     Legendario
# 414                 Regirock    580   80     100      200     Legendario
# 366      AltariaMega Altaria    590   75     110      110  No Legendario
# 776                   Goodra    600   90     100       70  No Legendario
# 705   ThundurusTherian Forme    580   79     105       70     Legendario
# 428       DeoxysNormal Forme    600   50     150       50     Legendario
# 306  GardevoirMega Gardevoir    618   68      85       65  No Legendario
# 715       MeloettaAria Forme    600  100      77       77  No Legendario
# 546                Cresselia    600  120      70      120  No Legendario
# 423                  Groudon    670  100     150      140     Legendario
# 549                  Darkrai    600   70      90       90     Legendario
# 717                 Genesect    600   71     120       95  No Legendario
#
#     Prediccion_Modelo
# 543     No Legendario
# 414     No Legendario
# 366        Legendario
# 776        Legendario
# 705     No Legendario
# 428     No Legendario
# 306        Legendario
# 715        Legendario
# 546        Legendario
# 423     No Legendario
# 549     No Legendario
# 717        Legendario

# %% [markdown]
# ### Preguntas finales
# 1. Sobre la matriz de confusión, interprete los resultados obtenidos. Con sus palabras defina que significa cada tipo de error. ¿Elegiría a Pokémon ubicados en FP o FN para su equipo?
#
#     **La matriz de confusión permite distinguir los aciertos versus los errores del modelo. Los verdaderos negativos corresponden a Pokémon no legendarios que fueron clasificados correctamente como no legendarios. Por otro lado, están los verdaderos positivos son Pokémon legendarios que el modelo identificó correctamente como legendarios.**
#
#     **Continuando, un falso positivo ocurre cuando el modelo predice que un Pokémon es legendario, aunque en realidad no lo sea. Esto puede pasar cuando un Pokémon no legendario tiene estadísticas altas o características similares a las de un legendario. En cambio, un falso negativo ocurre cuando el modelo predice que un Pokémon no es legendario, cuando realmente sí lo es. Este error es especialmente importante, porque representa un Pokémon legendario real que el modelo no logró detectar.**
#
#     **Si el objetivo fuera formar un equipo con Pokémon realmente legendarios, elegiría Pokémon ubicados en FN antes que en FP. Los FN sí son legendarios reales, aunque el modelo los haya clasificado incorrectamente como no legendarios. En cambio, los FP solo fueron predichos como legendarios por el modelo, pero en realidad no pertenecen a esa clase.**
#
# 2. Busque un caso mal clasificado por el modelo, e interprete por qué cree que el modelo se equivocó en ese caso.
#
#     **Para responder esta pregunta, nos basamos en la tabla de Pokémon mal clasificados que se generó en la sección de análisis de errores. Ahí se muestran los casos en los que la predicción del modelo no coincidió con la etiqueta real del dataset.**
#
#     **Cuando el caso es un falso positivo, quiere decir que el Pokémon no era legendario, pero el modelo lo clasificó como si lo fuera. Esto puede pasar porque algunos Pokémon no legendarios tienen estadísticas bastante altas, por ejemplo en Total, Attack, Sp. Atk o Speed. Entonces, desde lo que ve el modelo, pueden parecerse a ciertos Pokémon legendarios.**
#
#     **Por otro lado, cuando se trata de un falso negativo, significa que el Pokémon sí era legendario, pero el modelo lo clasificó como no legendario. Este tipo de error puede aparecer cuando sus estadísticas no son tan distintas a las de otros Pokémon comunes, o cuando el modelo no está considerando otra información importante, como el tipo, la generación o características propias del Pokémon dentro del juego**
#
#     **En conclusión, los errores del modelo se pueden explicar por una limitación en las variables utilizadas. El modelo aprende principalmente a partir de estadísticas numéricas de combate, pero que un Pokémon sea legendario no depende solo de tener valores altos en esas estadísticas.**
#
# 3. ¿Cúal fue el mayor desafío que enfrentó al realizar esta tarea? ¿Cómo lo solucionó?
#
#     **El mayor desafío fue definir correctamente cómo seleccionar el mejor modelo. Al inicio podía parecer que el mejor modelo debía ser el que tuviera la menor pérdida de validación. Sin embargo, se aclaró que esta pérdida se usa principalmente para guardar el mejor checkpoint durante el entrenamiento de cada arquitectura.**
#
#     **Para comparar arquitecturas distintas, fue necesario elegir una métrica alineada con el objetivo del problema. Como se buscaba identificar Pokémon legendarios y el dataset estaba desbalanceado, se decidió no usar `accuracy` como métrica principal. En su lugar, se tomaron en cuenta `precision`, `recall` y `F1-score`, dando prioridad al `F1-score` y después al `recall`.**
#
#     **Este desafío se resolvió separando dos decisiones: primero, usar la pérdida de validación para seleccionar el mejor checkpoint de cada modelo; y segundo, comparar los modelos finales con métricas de clasificación enfocadas en la identificación de Pokémon legendarios.**

# %% [markdown]
# ### IA Generativa
#
# Con el fin de ocupar IA Generativa de manera responsable, se les pide que respondan a las siguientes preguntas:
# 1. ¿Utilizó alguna herramienta de IA Generativa para realizar esta tarea? En caso afirmativo, indique cuál o cuáles herramientas utilizó.
#
# R:  **Sí, se utilizó Chat GPT como herramienta.**
#
# 2. ¿En qué parte o partes de la tarea utilizó estas herramientas?
#
# R: **La utilizamos como apoyo para comprender la estructura del problema, revisar la coherencia metodológica del entrenamiento, analizar la diferencia entre pérdida de validación y métricas de evaluación, y mejorar la redacción de las justificaciones. Además, para darle un orden a cada celda con el fin  de que sea más fácil de leer y entender.**
#
# **Se utilizó para crear los modelos de las arquitecturas simple, media y compleja, adaptándolos a la estructura del tutorial y a los resultados obtenidos en el notebook.**
#
# **También se utilizó para revisar posibles errores conceptuales, como la selección del mejor modelo, la interpretación de precision, recall y F1-score, y la explicación de la matriz de confusión.**
